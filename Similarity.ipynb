# %% [markdown]
# # Establishing Similarity of Countries
#
#     The goal of this project is to find the top ten most similar
#     countries and the top ten least similar countries in a certain
#     year (in this case only African countries, as the focus is on
#     the African continent) based on the UN general debates scripts of
#     1970 to 2016.
#
#     The similarity function created here can be used in different
#     contexts by just changing the variables

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import operator
import re
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
country_geo = 'world-countries.json'
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.9.11  |       hecc5488_0         143 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     conda-4.7.12               |           py36_0         3.0 MB  conda-forge
#     openssl-1.1.1c             |       h01d97ff_0         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.2 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-1 --> conda-forge::ca-certificates-2019.9.11-hecc5488_0
#   conda                      pkgs/main::conda-4.7.11-py36_0 --> conda-forge::conda-4.7.12-py36_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#   openssl              pkgs/main::openssl-1.1.1c-h1de35cc_1 --> conda-forge::openssl-1.1.1c-h01d97ff_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 143 KB    | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# openssl-1.1.1c       | 1.9 MB    | ##################################### | 100%
# conda-4.7.12         | 3.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# - peak into data

# %%
data = pd.read_csv('un-general-debates.csv')
data.head()
# Out:
#    session  year country                                               text
# 0       44  1989     MDV  ﻿It is indeed a pleasure for me and the member...
# 1       44  1989     FIN  ﻿\nMay I begin by congratulating you. Sir, on ...
# 2       44  1989     NER  ﻿\nMr. President, it is a particular pleasure ...
# 3       44  1989     URY  ﻿\nDuring the debate at the fortieth session o...
# 4       44  1989     ZWE  ﻿I should like at the outset to express my del...

# %% [markdown]
#  ## Linking and merges performed to enable a more elaborate analysis
#  - source of iso code dataset:
#        https://unstats.un.org/unsd/methodology/m49/overview/
# - The data set represents country names with their 3-letter ISO-alpha
# - To convert the ISO codes into country names, performed a left join
# - Dataset also includes region(continent) to enable filtering of African countries
# - Removed a duplicate column, "ISO-alpha3 Code"

# %%
data = pd.read_csv('un-general-debates.csv').drop('session', axis=1)
country_names = pd.read_excel ('UNSD — Methodology.xlsx')
data = pd.merge(data, country_names[['Region Name','Country or Area','ISO-alpha3 Code']],
             how='left', left_on='country', right_on='ISO-alpha3 Code')
data.drop('ISO-alpha3 Code',axis=1, inplace=True)
data.rename(columns = {'Country or Area': 'country_name'}, inplace = True)
data.head()
# Out:
#    year country                                               text  \
# 0  1989     MDV  ﻿It is indeed a pleasure for me and the member...
# 1  1989     FIN  ﻿\nMay I begin by congratulating you. Sir, on ...
# 2  1989     NER  ﻿\nMr. President, it is a particular pleasure ...
# 3  1989     URY  ﻿\nDuring the debate at the fortieth session o...
# 4  1989     ZWE  ﻿I should like at the outset to express my del...
#
#   Region Name country_name
# 0        Asia     Maldives
# 1      Europe      Finland
# 2      Africa        Niger
# 3    Americas      Uruguay
# 4      Africa     Zimbabwe

# %% [markdown]
# - Limiting country of interests to the  Africa continent

# %%
data = data.loc [data['Region Name']=='Africa']
data.nunique()
# Out:
# year              46
# country           54
# text            2159
# Region Name        1
# country_name      54
# dtype: int64

# %% [markdown]
# ## Data cleaning and binning
# 1. remove digits

# %%
def clean(s):    
    # Remove any tags:
    cleaned = re.sub(r"(?s)<.?>", " ", s)
    # Keep only regular chars:
    cleaned = re.sub(r"[^A-Za-z(),*!?\'\`]", " ", cleaned)
    # Remove unicode chars
    cleaned = re.sub("\\\\u(.){4}", " ", cleaned)
    return cleaned.strip()

# clean text
data['text'] = data.text.apply(lambda x: clean(x))
# remove data with null value in year column
data = data[data['year'].notnull()]

# %% [markdown]
# 2. Group data by country and into 5 year periods

# %%
data['year'] = (data['year'] / 5).astype(int)*5
data = data.groupby(['country', 'year', 'country_name'])['text'].apply(list)
data = data.apply(lambda x: ''.join(x))
data = data.reset_index(drop=False)

data[:20]
# Out:
#    country  year country_name  \
# 0      AGO  1975       Angola
# 1      AGO  1980       Angola
# 2      AGO  1985       Angola
# 3      AGO  1990       Angola
# 4      AGO  1995       Angola
# 5      AGO  2000       Angola
# 6      AGO  2005       Angola
# 7      AGO  2010       Angola
# 8      AGO  2015       Angola
# 9      BDI  1970      Burundi
# 10     BDI  1975      Burundi
# 11     BDI  1980      Burundi
# 12     BDI  1985      Burundi
# 13     BDI  1990      Burundi
# 14     BDI  1995      Burundi
# 15     BDI  2000      Burundi
# 16     BDI  2005      Burundi
# 17     BDI  2010      Burundi
# 18     BDI  2015      Burundi
# 19     BEN  1970        Benin
#
#                                                  text
# 0   On analysing the agenda of the thirty third se...
# 1   A few days ago, we had the legitimate satisfac...
# 2   Mr  President, today I have the honour of addr...
# 3   Allow me first to congratulate Mr  Shihabi on ...
# 4   Allow me at the outset to congratulate Mr  Ism...
# 5   Allow me, on behalf of my Government and in my...
# 6   I am  particularly honoured to address the Gen...
# 7   On behalf of  the President of the Republic of...
# 8   At the outset, on behalf of the President of A...
# 9   Mr  President, this great Assembly made a very...
# 10  I hope   am not too much mistaken if I say tha...
# 11  Once again I am honoured to head the delegatio...
# 12  Mr   MBON IMPA (Burundi)  As I have the honour...
# 13  I have the honour, Mr  President, of conveying...
# 14  The Burundi delegation, which I have the honou...
# 15  It is an honour for me to address the General ...
# 16  At  the outset, I would like to join previous ...
# 17  On this  special occasion, when I have the hon...
# 18  I would like first to thank God Almighty for g...
# 19  May I be allowed, on behalf of my delegation a...

# %% [markdown]
# 3. Create 5000 TF-IDF features, using 3-gram

# %%
num_features = 5000
tfidf = TfidfVectorizer(max_features = num_features, strip_accents='unicode',
                        lowercase=True, stop_words='english', ngram_range=(1,3))
print('Fitting Data...')
tfidf.fit(data['text'].values.astype('U'))

print('Starting Transform...')
text_tfidf = tfidf.transform(data['text'])

print('Label and Incorporate TF-IDF...')
data_array = pd.DataFrame(text_tfidf.toarray())
feature_names = tfidf.get_feature_names()

for i in range(num_features):
    feature_names[i] = 'TF_' + feature_names[i]

data_array.columns = feature_names
data = pd.concat([data, data_array], axis=1)

data[:10]
# Out:
# Fitting Data...
# Starting Transform...
# Label and Incorporate TF-IDF...
#   country  year country_name  \
# 0     AGO  1975       Angola
# 1     AGO  1980       Angola
# 2     AGO  1985       Angola
# 3     AGO  1990       Angola
# 4     AGO  1995       Angola
# 5     AGO  2000       Angola
# 6     AGO  2005       Angola
# 7     AGO  2010       Angola
# 8     AGO  2015       Angola
# 9     BDI  1970      Burundi
#
#                                                 text  TF_ababa  TF_abandon  \
# 0  On analysing the agenda of the thirty third se...  0.000000    0.000000
# 1  A few days ago, we had the legitimate satisfac...  0.006225    0.000000
# 2  Mr  President, today I have the honour of addr...  0.000000    0.000000
# 3  Allow me first to congratulate Mr  Shihabi on ...  0.009656    0.010041
# 4  Allow me at the outset to congratulate Mr  Ism...  0.000000    0.009256
# 5  Allow me, on behalf of my Government and in my...  0.000000    0.007752
# 6  I am  particularly honoured to address the Gen...  0.000000    0.000000
# 7  On behalf of  the President of the Republic of...  0.007028    0.000000
# 8  At the outset, on behalf of the President of A...  0.000000    0.000000
# 9  Mr  President, this great Assembly made a very...  0.003431    0.000000
#
#    TF_abide  TF_ability  TF_abject  TF_abject poverty  ...  TF_yugoslavia  \
# 0  0.000000    0.000000   0.000000                0.0  ...       0.000000
# 1  0.000000    0.000000   0.000000                0.0  ...       0.000000
# 2  0.000000    0.002424   0.000000                0.0  ...       0.000000
# 3  0.005084    0.000000   0.000000                0.0  ...       0.027618
# 4  0.000000    0.002844   0.000000                0.0  ...       0.005091
# 5  0.015699    0.009529   0.000000                0.0  ...       0.000000
# 6  0.000000    0.005599   0.000000                0.0  ...       0.000000
# 7  0.000000    0.000000   0.000000                0.0  ...       0.000000
# 8  0.000000    0.019756   0.000000                0.0  ...       0.000000
# 9  0.003613    0.002193   0.003743                0.0  ...       0.000000
#
#    TF_zaire  TF_zambia  TF_zimbabwe  TF_zimbabwe namibia  TF_zionism  \
# 0  0.012245   0.017640     0.073397             0.012450     0.03735
# 1  0.000000   0.006494     0.010808             0.000000     0.01375
# 2  0.010986   0.000000     0.003292             0.000000     0.00000
# 3  0.000000   0.000000     0.004191             0.007109     0.00000
# 4  0.012890   0.000000     0.000000             0.000000     0.00000
# 5  0.000000   0.007776     0.019413             0.000000     0.00000
# 6  0.000000   0.000000     0.015209             0.000000     0.00000
# 7  0.000000   0.000000     0.000000             0.000000     0.00000
# 8  0.000000   0.000000     0.000000             0.000000     0.00000
# 9  0.009938   0.014316     0.020848             0.000000     0.00000
#
#    TF_zionist   TF_zone  TF_zone peace  TF_zones
# 0    0.000000  0.013603       0.019485  0.000000
# 1    0.004201  0.005008       0.007173  0.000000
# 2    0.005119  0.009153       0.008740  0.000000
# 3    0.000000  0.000000       0.000000  0.004573
# 4    0.000000  0.010740       0.005128  0.000000
# 5    0.000000  0.005997       0.000000  0.000000
# 6    0.000000  0.014094       0.020188  0.000000
# 7    0.000000  0.000000       0.000000  0.000000
# 8    0.000000  0.000000       0.000000  0.000000
# 9    0.027784  0.005520       0.000000  0.003250
#
# [10 rows x 5004 columns]

# %% [markdown]
# 4. Obtain a list of TF-IDF features and assess their applicability

# %%
features = data.columns.tolist()
for i in ['year', 'country', 'country_name', 'text']:
    features.remove(i)
features
# Out:
# ['TF_ababa',
#  'TF_abandon',
#  'TF_abide',
#  'TF_ability',
#  'TF_abject',
#  'TF_abject poverty',
#  'TF_able',
#  'TF_abroad',
#  'TF_absence',
#  'TF_absolute',
#  'TF_absolutely',
#  'TF_abuja',
#  'TF_abuse',
#  'TF_accelerate',
#  'TF_accelerated',
#  'TF_accept',
#  'TF_acceptable',
#  'TF_acceptance',
#  'TF_accepted',
#  'TF_access',
#  'TF_accession',
#  'TF_accession independence',
#  'TF_accommodation',
#  'TF_accompanied',
#  'TF_accomplished',
#  'TF_accord',
#  'TF_accordance',
#  'TF_accorded',
#  'TF_according',
#  'TF_accordingly',
#  'TF_accords',
#  'TF_account',
#  'TF_accountability',
#  'TF_achieve',
#  'TF_achieve peace',
#  'TF_achieved',
#  'TF_achievement',
#  'TF_achievements',
#  'TF_achieving',
#  'TF_acknowledge',
#  'TF_acknowledged',
#  'TF_acquire',
#  'TF_acquired',
#  'TF_acquisition',
#  'TF_act',
#  'TF_acting',
#  'TF_action',
#  'TF_action adopted',
#  'TF_action african',
#  'TF_action african economic',
#  'TF_action international',
#  'TF_action taken',
#  'TF_actions',
#  'TF_active',
#  'TF_active solidarity',
#  'TF_actively',
#  'TF_activities',
#  'TF_activity',
#  'TF_actors',
#  'TF_acts',
#  'TF_acts aggression',
#  'TF_actual',
#  'TF_actually',
#  'TF_acute',
#  'TF_ad',
#  'TF_ad hoc',
#  'TF_ad hoc committee',
#  'TF_adapt',
#  'TF_adaptation',
#  'TF_adapted',
#  'TF_add',
#  'TF_added',
#  'TF_addis',
#  'TF_addis ababa',
#  'TF_addition',
#  'TF_additional',
#  'TF_address',
#  'TF_address assembly',
#  'TF_addressed',
#  'TF_addressing',
#  'TF_adequate',
#  'TF_adequately',
#  'TF_adhere',
#  'TF_adherence',
#  'TF_adjustment',
#  'TF_adjustment programmes',
#  'TF_administering',
#  'TF_administering power',
#  'TF_administration',
#  'TF_administrative',
#  'TF_admiration',
#  'TF_admission',
#  'TF_admit',
#  'TF_admitted',
#  'TF_adopt',
#  'TF_adopted',
#  'TF_adopted general',
#  'TF_adopted general assembly',
#  'TF_adopted resolution',
#  'TF_adopting',
#  'TF_adoption',
#  'TF_advance',
#  'TF_advanced',
#  'TF_advancement',
#  'TF_advances',
#  'TF_advancing',
#  'TF_advantage',
#  'TF_advantages',
#  'TF_advent',
#  'TF_adverse',
#  'TF_advisory',
#  'TF_advocate',
#  'TF_advocated',
#  'TF_advocates',
#  'TF_aegis',
#  'TF_affairs',
#  'TF_affairs states',
#  'TF_affect',
#  'TF_affected',
#  'TF_affecting',
#  'TF_affects',
#  'TF_affirm',
#  'TF_affirmed',
#  'TF_afflicted',
#  'TF_afford',
#  'TF_afghan',
#  'TF_afghanistan',
#  'TF_africa',
#  'TF_africa asia',
#  'TF_africa continent',
#  'TF_africa continue',
#  'TF_africa continues',
#  'TF_africa development',
#  'TF_africa economic',
#  'TF_africa international',
#  'TF_africa middle',
#  'TF_africa middle east',
#  'TF_africa namibia',
#  'TF_africa particular',
#  'TF_africa people',
#  'TF_africa people organization',
#  'TF_africa united',
#  'TF_africa world',
#  'TF_african',
#  'TF_african continent',
#  'TF_african countries',
#  'TF_african development',
#  'TF_african development community',
#  'TF_african economic',
#  'TF_african economic recovery',
#  'TF_african government',
#  'TF_african leaders',
#  'TF_african national',
#  'TF_african national congress',
#  'TF_african people',
#  'TF_african peoples',
#  'TF_african regime',
#  'TF_african republic',
#  'TF_african states',
#  'TF_african states ecowas',
#  'TF_african union',
#  'TF_african unity',
#  'TF_african unity oau',
#  'TF_africans',
#  'TF_age',
#  'TF_agencies',
#  'TF_agency',
#  'TF_agenda',
#  'TF_agenda development',
#  'TF_agenda peace',
#  'TF_aggravated',
#  'TF_aggression',
#  'TF_aggressive',
#  'TF_ago',
#  'TF_agree',
#  'TF_agreed',
#  'TF_agreement',
#  'TF_agreement reached',
#  'TF_agreement signed',
#  'TF_agreements',
#  'TF_agricultural',
#  'TF_agriculture',
#  'TF_ahead',
#  'TF_ahmed',
#  'TF_aid',
#  'TF_aids',
#  'TF_aids pandemic',
#  'TF_aim',
#  'TF_aimed',
#  'TF_aims',
#  'TF_air',
#  'TF_al',
#  'TF_al quds',
#  'TF_alarming',
#  'TF_algeria',
#  'TF_algiers',
#  'TF_ali',
#  'TF_alia',
#  'TF_aligned',
#  'TF_aligned countries',
#  'TF_aligned movement',
#  'TF_alignment',
#  'TF_alike',
#  'TF_alleviate',
#  'TF_alliance',
#  'TF_alliances',
#  'TF_allies',
#  'TF_allow',
#  'TF_allowed',
#  'TF_allowing',
#  'TF_alternative',
#  'TF_ambassador',
#  'TF_ambition',
#  'TF_ambitions',
#  'TF_ambitious',
#  'TF_america',
#  'TF_american',
#  'TF_anachronistic',
#  'TF_analysis',
#  'TF_anc',
#  'TF_angola',
#  'TF_angola mozambique',
#  'TF_angolan',
#  'TF_angolan people',
#  'TF_anguish',
#  'TF_annan',
#  'TF_annex',
#  'TF_annexation',
#  'TF_anniversary',
#  'TF_anniversary united',
#  'TF_anniversary united nations',
#  'TF_announced',
#  'TF_annual',
#  'TF_answer',
#  'TF_anti',
#  'TF_anti personnel',
#  'TF_anxiety',
#  'TF_apart',
#  'TF_apartheid',
#  'TF_apartheid regime',
#  'TF_apartheid south',
#  'TF_apartheid south africa',
#  'TF_apparent',
#  'TF_appeal',
#  'TF_appeal international',
#  'TF_appeal international community',
#  'TF_appeals',
#  'TF_appear',
#  'TF_appears',
#  'TF_applaud',
#  'TF_application',
#  'TF_applied',
#  'TF_applies',
#  'TF_apply',
#  'TF_appointed',
#  'TF_appointment',
#  'TF_appreciate',
#  'TF_appreciated',
#  'TF_appreciates',
#  'TF_appreciation',
#  'TF_appreciation secretary',
#  'TF_appreciation secretary general',
#  'TF_approach',
#  'TF_approaches',
#  'TF_appropriate',
#  'TF_appropriate measures',
#  'TF_approved',
#  'TF_approximately',
#  'TF_april',
#  'TF_arab',
#  'TF_arab countries',
#  'TF_arab israeli',
#  'TF_arab jamahiriya',
#  'TF_arab maghreb',
#  'TF_arab nation',
#  'TF_arab republic',
#  'TF_arab states',
#  'TF_arab territories',
#  'TF_arab territories occupied',
#  'TF_arab world',
#  'TF_arabs',
#  'TF_arbitrary',
#  'TF_archipelago',
#  'TF_arduous',
#  'TF_area',
#  'TF_areas',
#  'TF_arena',
#  'TF_arise',
#  'TF_arising',
#  'TF_armaments',
#  'TF_armed',
#  'TF_armed conflict',
#  'TF_armed conflicts',
#  'TF_armed forces',
#  'TF_armed groups',
#  'TF_armed struggle',
#  'TF_arms',
#  'TF_arms light',
#  'TF_arms light weapons',
#  'TF_arms race',
#  'TF_army',
#  'TF_aroused',
#  'TF_arrangements',
#  'TF_arrive',
#  'TF_arrogance',
#  'TF_arsenals',
#  'TF_article',
#  'TF_arusha',
#  'TF_asia',
#  'TF_asia latin',
#  'TF_asia latin america',
#  'TF_asian',
#  'TF_aside',
#  'TF_ask',
#  'TF_asked',
#  'TF_asking',
#  'TF_aspect',
#  'TF_aspects',
#  'TF_aspiration',
#  'TF_aspirations',
#  'TF_aspirations people',
#  'TF_aspirations peoples',
#  'TF_aspire',
#  'TF_assembly',
#  'TF_assembly adopted',
#  'TF_assembly devoted',
#  'TF_assembly eighth',
#  'TF_assembly eighth session',
#  'TF_assembly heads',
#  'TF_assembly heads state',
#  'TF_assembly ninth',
#  'TF_assembly ninth session',
#  'TF_assembly resolution',
#  'TF_assembly resolutions',
#  'TF_assembly security',
#  'TF_assembly security council',
#  'TF_assembly session',
#  'TF_assembly united',
#  'TF_assembly united nations',
#  'TF_assess',
#  'TF_assessment',
#  'TF_assist',
#  'TF_assistance',
#  'TF_assistance international',
#  'TF_assistance international community',
#  'TF_assisting',
#  'TF_associate',
#  'TF_associated',
#  'TF_association',
#  'TF_assume',
#  'TF_assumed',
#  'TF_assuming',
#  'TF_assumption',
#  'TF_assure',
#  'TF_assured',
#  'TF_atlantic',
#  'TF_atmosphere',
#  'TF_atomic',
#  'TF_atrocities',
#  'TF_attach',
#  'TF_attached',
#  'TF_attaches',
#  'TF_attack',
#  'TF_attacks',
#  'TF_attain',
#  'TF_attained',
#  'TF_attaining',
#  'TF_attainment',
#  'TF_attempt',
#  'TF_attempted',
#  'TF_attempting',
#  'TF_attempts',
#  'TF_attention',
#  'TF_attention international',
#  'TF_attention international community',
#  'TF_attitude',
#  'TF_attitudes',
#  'TF_august',
#  'TF_auspices',
#  'TF_auspices united',
#  'TF_auspices united nations',
#  'TF_authentic',
#  'TF_authentic representative',
#  'TF_authorities',
#  'TF_authority',
#  'TF_autonomy',
#  'TF_avail',
#  'TF_available',
#  'TF_average',
#  'TF_avert',
#  'TF_avoid',
#  'TF_aware',
#  'TF_awareness',
#  'TF_away',
#  'TF_background',
#  'TF_bad',
#  'TF_balance',
#  'TF_balance payments',
#  'TF_balanced',
#  'TF_ban',
#  'TF_ban ki',
#  'TF_ban ki moon',
#  'TF_ban treaty',
#  'TF_bank',
#  'TF_bantustans',
#  'TF_barbaric',
#  'TF_barriers',
#  'TF_base',
#  'TF_based',
#  'TF_based justice',
#  'TF_bases',
#  'TF_basic',
#  'TF_basic human',
#  'TF_basin',
#  'TF_basis',
#  'TF_battle',
#  'TF_bear',
#  'TF_bearing',
#  'TF_bears',
#  'TF_bed',
#  'TF_began',
#  'TF_begin',
#  'TF_beginning',
#  'TF_begun',
#  'TF_behalf',
#  'TF_behalf delegation',
#  'TF_behalf government',
#  'TF_behalf government people',
#  'TF_behalf people',
#  'TF_behaviour',
#  'TF_beijing',
#  'TF_beings',
#  'TF_belief',
#  'TF_believe',
#  'TF_believed',
#  'TF_believes',
#  'TF_belong',
#  'TF_belongs',
#  'TF_beneficial',
#  'TF_benefit',
#  'TF_benefits',
#  'TF_benin',
#  'TF_beset',
#  'TF_best',
#  'TF_best wishes',
#  'TF_better',
#  'TF_better future',
#  'TF_better world',
#  'TF_big',
#  'TF_big powers',
#  'TF_bilateral',
#  'TF_bilateral multilateral',
#  'TF_billion',
#  'TF_binding',
#  'TF_biological',
#  'TF_birth',
#  'TF_bissau',
#  'TF_bitter',
#  'TF_black',
#  'TF_black majority',
#  'TF_blacks',
#  'TF_blind',
#  'TF_blocs',
#  'TF_blood',
#  'TF_bloodshed',
#  'TF_bloody',
#  'TF_bodies',
#  'TF_body',
#  'TF_bold',
#  'TF_border',
#  'TF_borders',
#  'TF_born',
#  'TF_borne',
#  'TF_bosnia',
#  'TF_bosnia herzegovina',
#  'TF_botswana',
#  'TF_bound',
#  'TF_boundaries',
#  'TF_boundary',
#  'TF_boutros',
#  'TF_boutros boutros',
#  'TF_boutros boutros ghali',
#  'TF_boutros ghali',
#  'TF_break',
#  'TF_breaking',
#  'TF_bretton',
#  'TF_bretton woods',
#  'TF_bretton woods institutions',
#  'TF_brief',
#  'TF_briefly',
#  'TF_brilliant',
#  'TF_bring',
#  'TF_bring peace',
#  'TF_bringing',
#  'TF_brings',
#  'TF_britain',
#  'TF_british',
#  'TF_broad',
#  'TF_broader',
#  'TF_brother',
#  'TF_brotherhood',
#  'TF_brotherly',
#  'TF_brothers',
#  'TF_brothers sisters',
#  'TF_brought',
#  'TF_brutal',
#  'TF_budget',
#  'TF_build',
#  'TF_building',
#  'TF_built',
#  'TF_burden',
#  'TF_bureau',
#  'TF_burkina',
#  'TF_burkina faso',
#  'TF_burning',
#  'TF_burundi',
#  'TF_business',
#  'TF_cairo',
#  'TF_called',
#  'TF_calling',
#  'TF_calls',
#  'TF_calm',
#  'TF_cambodia',
#  'TF_came',
#  'TF_cameroon',
#  'TF_camp',
#  'TF_camp david',
#  'TF_campaign',
#  'TF_camps',
#  'TF_cancellation',
#  'TF_capabilities',
#  'TF_capability',
#  'TF_capable',
#  'TF_capacities',
#  'TF_capacity',
#  'TF_cape',
#  'TF_cape verde',
#  'TF_capita',
#  'TF_capital',
#  'TF_cardinal',
#  'TF_care',
#  'TF_careful',
#  'TF_carefully',
#  'TF_caribbean',
#  'TF_carried',
#  'TF_carry',
#  'TF_carrying',
#  'TF_case',
#  'TF_cases',
#  'TF_cast',
#  'TF_catastrophe',
#  'TF_catastrophic',
#  'TF_category',
#  'TF_cause',
#  'TF_cause peace',
#  'TF_caused',
#  'TF_causes',
#  'TF_causing',
#  'TF_cease',
#  'TF_ceasefire',
#  'TF_celebrate',
#  'TF_celebration',
#  'TF_cent',
#  'TF_cent gross',
#  'TF_cent gross national',
#  'TF_central',
#  'TF_central africa',
#  'TF_central african',
#  'TF_central african republic',
#  'TF_central america',
#  'TF_central role',
#  'TF_centre',
#  'TF_centres',
#  'TF_centuries',
#  'TF_century',
#  'TF_certain',
#  'TF_certain countries',
#  'TF_certain states',
#  'TF_certainly',
#  'TF_cessation',
#  'TF_cessation hostilities',
#  'TF_chad',
#  'TF_chadian',
#  'TF_chair',
#  'TF_chairman',
#  'TF_challenge',
#  'TF_challenges',
#  'TF_challenges facing',
#  'TF_challenging',
#  'TF_chance',
#  'TF_chances',
#  'TF_change',
#  'TF_changed',
#  'TF_changes',
#  'TF_changing',
#  'TF_chaos',
#  'TF_chapter',
#  'TF_chapter vii',
#  'TF_chapter vii charter',
#  'TF_character',
#  'TF_characterized',
#  'TF_charter',
#  'TF_charter organization',
#  'TF_charter united',
#  'TF_charter united nations',
#  'TF_chemical',
#  'TF_chemical weapons',
#  'TF_cherish',
#  'TF_chief',
#  'TF_child',
#  'TF_children',
#  'TF_china',
#  'TF_china taiwan',
#  'TF_chinese',
#  'TF_choice',
#  'TF_choose',
#  'TF_chosen',
#  'TF_chronic',
#  'TF_circumstances',
#  'TF_citizen',
#  'TF_citizens',
#  'TF_city',
#  'TF_civil',
#  'TF_civil society',
#  'TF_civil war',
#  'TF_civilian',
#  'TF_civilians',
#  'TF_civilization',
#  'TF_civilizations',
#  'TF_civilized',
#  'TF_claim',
#  'TF_claimed',
#  'TF_claims',
#  'TF_clear',
#  'TF_clearly',
#  'TF_climate',
#  'TF_climate change',
#  'TF_climate peace',
#  'TF_close',
#  'TF_closely',
#  'TF_closer',
#  'TF_coalition',
#  'TF_coast',
#  'TF_coastal',
#  'TF_code',
#  'TF_coexistence',
#  'TF_coherent',
#  'TF_cohesion',
#  'TF_cold',
#  'TF_cold war',
#  'TF_collaboration',
#  'TF_collapse',
#  'TF_collective',
#  'TF_collective action',
#  'TF_collective responsibility',
#  'TF_collective security',
#  'TF_collectively',
#  'TF_colonial',
#  'TF_colonial countries',
#  'TF_colonial countries peoples',
#  'TF_colonial domination',
#  'TF_colonialism',
#  'TF_colonialism racism',
#  'TF_colonialist',
#  'TF_colonies',
#  'TF_colonization',
#  'TF_combat',
#  'TF_combatants',
#  'TF_combating',
#  'TF_combined',
#  'TF_come',
#  'TF_comes',
#  'TF_coming',
#  'TF_command',
#  'TF_commend',
#  'TF_commend secretary',
#  'TF_commend secretary general',
#  'TF_commendable',
#  'TF_commensurate',
#  'TF_commercial',
#  'TF_commission',
#  'TF_commission human',
#  'TF_commissioner',
#  'TF_commissioner refugees',
#  'TF_commit',
#  'TF_commitment',
#  'TF_commitments',
#  'TF_committed',
#  'TF_committee',
#  'TF_commodities',
#  'TF_commodity',
#  'TF_commodity prices',
#  'TF_common',
#  'TF_common destiny',
#  'TF_common fund',
#  'TF_common heritage',
#  'TF_commonwealth',
#  'TF_communication',
#  'TF_communications',
#  'TF_communities',
#  'TF_community',
#  'TF_community continue',
#  'TF_community nations',
#  'TF_community provide',
#  'TF_community support',
#  'TF_community united',
#  'TF_community united nations',
#  'TF_community west',
#  'TF_community west african',
#  'TF_comorian',
#  'TF_comoros',
#  'TF_companies',
#  'TF_compared',
#  'TF_compel',
#  'TF_compelled',
#  'TF_compensation',
#  'TF_competence',
#  'TF_competent',
#  'TF_competition',
#  'TF_complement',
#  'TF_complementarity',
#  'TF_complementary',
#  'TF_complete',
#  'TF_complete disarmament',
#  'TF_completed',
#  'TF_completely',
#  'TF_completion',
#  'TF_complex',
#  'TF_complexity',
#  'TF_compliance',
#  'TF_complicity',
#  'TF_comply',
#  'TF_composition',
#  'TF_compounded',
#  'TF_comprehensive',
#  'TF_comprehensive peace',
#  'TF_compromise',
#  'TF_conceived',
#  'TF_concept',
#  'TF_concepts',
#  'TF_concern',
#  'TF_concern international',
#  'TF_concern international community',
#  'TF_concerned',
#  'TF_concerning',
#  'TF_concerns',
#  'TF_concert',
#  'TF_concerted',
#  'TF_concerted action',
#  'TF_concerted efforts',
#  'TF_concessions',
#  'TF_conclude',
#  'TF_concluded',
#  'TF_concluding',
#  'TF_conclusion',
#  'TF_conclusions',
#  'TF_concord',
#  'TF_concrete',
#  'TF_concrete measures',
#  'TF_condemn',
#  'TF_condemnation',
#  'TF_condemned',
#  'TF_condemning',
#  'TF_condemns',
#  'TF_condition',
#  'TF_conditions',
#  'TF_condolences',
#  'TF_conducive',
#  'TF_conduct',
#  'TF_conducted',
#  'TF_conference',
#  'TF_conference environment',
#  'TF_conference environment development',
#  'TF_conference heads',
#  'TF_conference heads state',
#  'TF_conference held',
#  'TF_conference human',
#  'TF_conference law',
#  'TF_conference law sea',
#  'TF_conference middle',
#  'TF_conference middle east',
#  'TF_conference parties',
#  'TF_conference trade',
#  'TF_conference trade development',
#  'TF_conferences',
#  'TF_confidence',
#  'TF_confident',
#  'TF_confined',
#  'TF_confirm',
#  'TF_confirmed',
#  'TF_conflagration',
#  'TF_conflict',
#  'TF_conflict prevention',
#  'TF_conflict resolution',
#  'TF_conflict situations',
#  'TF_conflicts',
#  'TF_conflicts africa',
#  'TF_conformity',
#  'TF_confront',
#  'TF_confrontation',
#  'TF_confrontations',
#  'TF_confronted',
#  'TF_confronting',
#  'TF_congo',
#  'TF_congolese',
#  'TF_congratulate',
#  'TF_congratulate mr',
#  'TF_congratulating',
#  'TF_congratulations',
#  'TF_congratulations election',
#  'TF_congratulations election presidency',
#  'TF_congratulations mr',
#  'TF_congress',
#  'TF_connection',
#  'TF_connexion',
#  'TF_conscience',
#  'TF_conscious',
#  'TF_consensus',
#  'TF_consequence',
#  'TF_consequences',
#  'TF_consequently',
#  'TF_consider',
#  'TF_considerable',
#  'TF_considerably',
#  'TF_consideration',
#  'TF_considerations',
#  'TF_considered',
#  'TF_considering',
#  'TF_considers',
#  'TF_consistent',
#  'TF_consistently',
#  'TF_consolidate',
#  'TF_consolidated',
#  'TF_consolidating',
#  'TF_consolidation',
#  'TF_constant',
#  'TF_constantly',
#  'TF_constitute',
#  'TF_constitutes',
#  'TF_constitution',
#  'TF_constitutional',
#  'TF_constraints',
#  'TF_construction',
#  'TF_constructive',
#  'TF_constructive dialogue',
#  'TF_consultation',
#  'TF_consultations',
#  'TF_contact',
#  'TF_contact group',
#  'TF_contacts',
#  'TF_contadora',
#  'TF_contain',
#  'TF_contained',
#  'TF_contains',
#  'TF_contemporary',
#  'TF_contempt',
#  'TF_content',
#  'TF_context',
#  'TF_continent',
#  'TF_continent africa',
#  'TF_continental',
#  'TF_continents',
#  'TF_continuation',
#  'TF_continue',
#  'TF_continue efforts',
#  'TF_continue support',
#  'TF_continue work',
#  'TF_continued',
#  'TF_continues',
#  'TF_continuing',
#  'TF_continuous',
#  'TF_contradictions',
#  'TF_contrary',
#  'TF_contribute',
#  'TF_contributed',
#  'TF_contributing',
#  'TF_contribution',
#  'TF_contributions',
#  'TF_control',
#  'TF_convene',
#  'TF_convened',
#  'TF_convening',
#  'TF_convening international',
#  'TF_convening international conference',
#  'TF_convention',
#  'TF_conventional',
#  'TF_conventional weapons',
#  'TF_conventions',
#  'TF_convey',
#  'TF_conviction',
#  'TF_convinced',
#  'TF_cooperate',
#  'TF_cooperation',
#  'TF_cooperation development',
#  'TF_coordinated',
#  'TF_coordination',
#  'TF_cope',
#  'TF_copenhagen',
#  'TF_core',
#  'TF_corporations',
#  'TF_correct',
#  'TF_corruption',
#  'TF_cost',
#  'TF_costs',
#  'TF_council',
#  'TF_council general',
#  'TF_council general assembly',
#  'TF_council resolution',
#  'TF_council resolutions',
#  'TF_count',
#  'TF_counter',
#  'TF_countries',
#  'TF_countries africa',
#  'TF_countries concerned',
#  'TF_countries continue',
#  'TF_countries developed',
#  'TF_countries developing',
#  'TF_countries developing countries',
#  'TF_countries economic',
#  'TF_countries especially',
#  'TF_countries held',
#  'TF_countries including',
#  'TF_countries international',
#  'TF_countries like',
#  'TF_countries need',
#  'TF_countries north',
#  'TF_countries particular',
#  'TF_countries particularly',
#  'TF_countries peoples',
#  'TF_countries region',
#  'TF_countries south',
#  'TF_countries united',
#  'TF_countries united nations',
#  'TF_countries world',
#  'TF_country',
#  'TF_country like',
#  'TF_country people',
#  'TF_coup',
#  'TF_coupled',
#  'TF_courage',
#  'TF_courageous',
#  'TF_course',
#  'TF_court',
#  'TF_court justice',
#  'TF_cover',
#  'TF_create',
#  'TF_create conditions',
#  'TF_created',
#  'TF_creating',
#  'TF_creation',
#  'TF_creative',
#  'TF_credibility',
#  'TF_credible',
#  'TF_credit',
#  'TF_creditors',
#  'TF_crime',
#  'TF_crime humanity',
#  'TF_crimes',
#  'TF_criminal',
#  'TF_criminal court',
#  'TF_crises',
#  'TF_crisis',
#  'TF_criteria',
#  'TF_critical',
#  'TF_critical economic',
#  'TF_critical economic situation',
#  'TF_cross',
#  'TF_crowned',
#  'TF_crucial',
#  'TF_cruel',
#  'TF_cuba',
#  'TF_cuban',
#  'TF_cuellar',
#  'TF_cultural',
#  'TF_culture',
#  'TF_cultures',
#  'TF_currency',
#  'TF_current',
#  'TF_current chairman',
#  'TF_current international',
#  'TF_current session',
#  'TF_currently',
#  'TF_cut',
#  'TF_cycle',
#  'TF_cypriot',
#  'TF_cyprus',
#  'TF_daily',
#  'TF_damage',
#  'TF_danger',
#  'TF_dangerous',
#  'TF_dangerously',
#  'TF_dangers',
#  'TF_darfur',
#  'TF_date',
#  'TF_david',
#  'TF_dawn',
#  'TF_day',
#  'TF_day day',
#  'TF_days',
#  'TF_days ago',
#  ...]

# %%
df = data.copy()
df['total'] = df[features].sum(axis=1).abs()
df = df.sort_values(by='total', ascending=True).reset_index(drop=True)
df[:30]
# Out:
#    country  year              country_name  \
# 0      MUS  2015                 Mauritius
# 1      BFA  2015              Burkina Faso
# 2      RWA  2015                    Rwanda
# 3      UGA  2015                    Uganda
# 4      GNQ  2015         Equatorial Guinea
# 5      MWI  2005                    Malawi
# 6      ERI  2015                   Eritrea
# 7      SSD  2015               South Sudan
# 8      SYC  2015                Seychelles
# 9      BFA  2010              Burkina Faso
# 10     GNQ  2000         Equatorial Guinea
# 11     SWZ  1995                  Eswatini
# 12     ETH  2015                  Ethiopia
# 13     CAF  2015  Central African Republic
# 14     MWI  1990                    Malawi
# 15     CAF  2000  Central African Republic
# 16     CAF  2010  Central African Republic
# 17     MWI  2015                    Malawi
# 18     LBY  2015                     Libya
# 19     SSD  2010               South Sudan
# 20     SEN  2015                   Senegal
# 21     GNQ  2010         Equatorial Guinea
# 22     MLI  2015                      Mali
# 23     GNB  2015             Guinea-Bissau
# 24     LBR  2015                   Liberia
# 25     GNQ  1990         Equatorial Guinea
# 26     MAR  2015                   Morocco
# 27     CPV  2015                Cabo Verde
# 28     MRT  2015                Mauritania
# 29     KEN  2015                     Kenya
#
#                                                  text  TF_ababa  TF_abandon  \
# 0   Twelve years ago, I bade farewell to the Assem...  0.010930    0.000000
# 1   It is my honour to address the Assembly as Pre...  0.025381    0.000000
# 2   The adoption of the Sustainable Development Go...  0.000000    0.000000
# 3   I congratulate you, Sir, on your election as P...  0.000000    0.000000
# 4   It is a pleasure for me to take the floor befo...  0.000000    0.000000
# 5   I would like to take this  opportunity to cong...  0.000000    0.000000
# 6   It is my pleasure, at the outset, to warmly co...  0.000000    0.000000
# 7   On behalf of my President, His Excellency Mr  ...  0.035326    0.000000
# 8   We the peoples of the United Nations, determin...  0.000000    0.000000
# 9   Sociopolitical crises, armed conflicts, the de...  0.000000    0.000000
# 10  The delegation of Equatorial Guinea congratula...  0.000000    0.000000
# 11  I bring with me from the Kingdom of Swaziland ...  0.000000    0.000000
# 12  I would like to begin by congratulating you, M...  0.062664    0.000000
# 13  The Head of State of the Transition, Her Excel...  0.000000    0.000000
# 14  On behalf of the Malawi delegation, I am pleas...  0.002534    0.000000
# 15  The fifty seventh session of the General Assem...  0.000000    0.000000
# 16  The theme chosen for the sixty eighth  session...  0.000000    0.004248
# 17  It gives me great pleasure to congratulate Mr ...  0.000000    0.000000
# 18  As the General Assembly gathers this year, we ...  0.000000    0.000000
# 19  It is a great honour  for me to address the As...  0.017437    0.006044
# 20  Senegal, through me, warmly congratulates the ...  0.000000    0.044953
# 21  We bring to this sixty eighth session of the  ...  0.000000    0.000000
# 22  On behalf of the Malian delegation, I would fi...  0.015110    0.000000
# 23  His Excellency Mr  Jos  Mario Vaz, President o...  0.000000    0.000000
# 24  On this auspicious occasion, the seventieth an...  0.040407    0.000000
# 25  The forty sixth session of the General Assembl...  0.000000    0.000000
# 26  King Mohammed VI has mandated me to convey his...  0.000000    0.000000
# 27  I would ask the indulgence of the Assembly tha...  0.000000    0.000000
# 28  It is an honour for me to deliver the statemen...  0.000000    0.000000
# 29  It is a pleasure for me to be addressing the G...  0.015028    0.015628
#
#     TF_abide  TF_ability  TF_abject  TF_abject poverty  ...  TF_zaire  \
# 0   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 1   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 2   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 3   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 4   0.000000    0.000000   0.026729           0.029625  ...   0.00000
# 5   0.000000    0.006453   0.005507           0.006104  ...   0.00000
# 6   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 7   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 8   0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 9   0.000000    0.002565   0.000000           0.000000  ...   0.00000
# 10  0.000000    0.003153   0.000000           0.000000  ...   0.00000
# 11  0.014449    0.005262   0.000000           0.000000  ...   0.00000
# 12  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 13  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 14  0.000000    0.001620   0.000000           0.000000  ...   0.00734
# 15  0.000000    0.002866   0.000000           0.000000  ...   0.00000
# 16  0.004301    0.000000   0.000000           0.000000  ...   0.00000
# 17  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 18  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 19  0.000000    0.003715   0.000000           0.000000  ...   0.00000
# 20  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 21  0.000000    0.003490   0.000000           0.000000  ...   0.00000
# 22  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 23  0.000000    0.043655   0.000000           0.000000  ...   0.00000
# 24  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 25  0.000000    0.004439   0.000000           0.000000  ...   0.00000
# 26  0.000000    0.019364   0.000000           0.000000  ...   0.00000
# 27  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 28  0.000000    0.000000   0.000000           0.000000  ...   0.00000
# 29  0.000000    0.000000   0.000000           0.000000  ...   0.00000
#
#     TF_zambia  TF_zimbabwe  TF_zimbabwe namibia  TF_zionism  TF_zionist  \
# 0    0.000000     0.000000                  0.0         0.0         0.0
# 1    0.000000     0.000000                  0.0         0.0         0.0
# 2    0.000000     0.000000                  0.0         0.0         0.0
# 3    0.000000     0.000000                  0.0         0.0         0.0
# 4    0.000000     0.000000                  0.0         0.0         0.0
# 5    0.005266     0.004383                  0.0         0.0         0.0
# 6    0.000000     0.000000                  0.0         0.0         0.0
# 7    0.000000     0.000000                  0.0         0.0         0.0
# 8    0.000000     0.000000                  0.0         0.0         0.0
# 9    0.000000     0.000000                  0.0         0.0         0.0
# 10   0.000000     0.012848                  0.0         0.0         0.0
# 11   0.002863     0.000000                  0.0         0.0         0.0
# 12   0.000000     0.000000                  0.0         0.0         0.0
# 13   0.000000     0.000000                  0.0         0.0         0.0
# 14   0.002644     0.000000                  0.0         0.0         0.0
# 15   0.000000     0.000000                  0.0         0.0         0.0
# 16   0.000000     0.000000                  0.0         0.0         0.0
# 17   0.000000     0.000000                  0.0         0.0         0.0
# 18   0.000000     0.000000                  0.0         0.0         0.0
# 19   0.000000     0.000000                  0.0         0.0         0.0
# 20   0.000000     0.000000                  0.0         0.0         0.0
# 21   0.000000     0.004741                  0.0         0.0         0.0
# 22   0.000000     0.000000                  0.0         0.0         0.0
# 23   0.000000     0.000000                  0.0         0.0         0.0
# 24   0.000000     0.000000                  0.0         0.0         0.0
# 25   0.000000     0.000000                  0.0         0.0         0.0
# 26   0.000000     0.000000                  0.0         0.0         0.0
# 27   0.000000     0.000000                  0.0         0.0         0.0
# 28   0.000000     0.000000                  0.0         0.0         0.0
# 29   0.000000     0.000000                  0.0         0.0         0.0
#
#      TF_zone  TF_zone peace  TF_zones      total
# 0   0.000000            0.0  0.000000  11.053116
# 1   0.000000            0.0  0.000000  11.922399
# 2   0.000000            0.0  0.000000  12.115164
# 3   0.000000            0.0  0.000000  13.136202
# 4   0.000000            0.0  0.000000  13.161770
# 5   0.000000            0.0  0.000000  13.584389
# 6   0.000000            0.0  0.000000  13.679593
# 7   0.000000            0.0  0.000000  14.010373
# 8   0.000000            0.0  0.000000  14.089964
# 9   0.003229            0.0  0.000000  14.170195
# 10  0.000000            0.0  0.000000  14.233214
# 11  0.000000            0.0  0.002600  14.800038
# 12  0.000000            0.0  0.000000  14.972318
# 13  0.000000            0.0  0.000000  15.052314
# 14  0.000000            0.0  0.002401  15.123819
# 15  0.000000            0.0  0.000000  15.568234
# 16  0.000000            0.0  0.000000  15.586233
# 17  0.000000            0.0  0.000000  15.591306
# 18  0.017948            0.0  0.000000  15.685091
# 19  0.000000            0.0  0.000000  15.700749
# 20  0.000000            0.0  0.000000  15.902044
# 21  0.000000            0.0  0.000000  15.935763
# 22  0.000000            0.0  0.000000  15.937590
# 23  0.000000            0.0  0.000000  15.955816
# 24  0.000000            0.0  0.000000  16.061104
# 25  0.000000            0.0  0.000000  16.103244
# 26  0.000000            0.0  0.000000  16.129114
# 27  0.000000            0.0  0.000000  16.130223
# 28  0.000000            0.0  0.000000  16.133851
# 29  0.000000            0.0  0.000000  16.138363
#
# [30 rows x 5005 columns]

# %% [markdown]
# ## The Similarity Function

# %%
def similarity(year, count=10, same_year=True):
    '''finds most similar and least similiar countries'''
    df = data.copy()
    primary = data[(data['year']==year)]
    for i in features:
        df[i] = [np.square(primary[i].values[0].astype(float) - x) for x in data[i]]
    
    df['total'] = df[features].sum(axis=1).abs()
    df = df.sort_values(by='total', ascending=True).reset_index(drop=True)
    if same_year == True:
        df = df[df['year'] == year]
        most_similar = df[1:1 + count].country_name
        least_similar = df[-count:].country_name
    else:
        most_similar = df[1:1 + count].country_name + [' ' for i in range(count)] + ['(' + str(i) + ')' for i in df[1:1 + count].year]
        least_similar = df[-count:].country_name + [' ' for i in range(count)] + ['(' + str(i) + ')' for i in df[-count:].year]
    print(str(year))
    print('most similar:')
    print(most_similar.values)
    print()
    print(str(year))
    print('least similar:')
    print(least_similar.values)
    print()
    print()
    return ''

# %%
similarity(1975)
# Out:
# 1975
# most similar:
# ['Mozambique' 'Guinea-Bissau' 'Cabo Verde' 'Sao Tome and Principe' 'Benin'
#  'Burundi' 'Guinea' 'Congo' 'Somalia' 'United Republic of Tanzania']
#
# 1975
# least similar:
# ['Gabon' 'Gambia' 'Seychelles' 'Central African Republic' 'Lesotho'
#  'Comoros' 'Burkina Faso' 'Malawi' 'Equatorial Guinea' 'Eswatini']
# ''

# %%
similarity(1975)
# Out:
# 1975
# most similar:
# ['Mozambique' 'Guinea-Bissau' 'Cabo Verde' 'Sao Tome and Principe' 'Benin'
#  'Burundi' 'Guinea' 'Congo' 'Somalia' 'United Republic of Tanzania']
#
# 1975
# least similar:
# ['Gabon' 'Gambia' 'Seychelles' 'Central African Republic' 'Lesotho'
#  'Comoros' 'Burkina Faso' 'Malawi' 'Equatorial Guinea' 'Eswatini']
# ''

# %%
similarity(1980)
# Out:
# 1980
# most similar:
# ['Mozambique' 'Guinea-Bissau' 'Zimbabwe' 'Guinea' 'Congo' 'Burundi'
#  'Sao Tome and Principe' 'Zambia' 'Ethiopia' 'United Republic of Tanzania']
#
# 1980
# least similar:
# ['Lesotho' 'Gambia' 'Chad' 'Burkina Faso' 'Côte d’Ivoire' 'Malawi'
#  'Central African Republic' 'Eswatini' 'Equatorial Guinea' 'South Africa']
# ''

# %%
similarity(1985)
# Out:
# 1985
# most similar:
# ['Mozambique' 'United Republic of Tanzania' 'Congo' 'Zambia' 'Djibouti'
#  'Cabo Verde' 'Zimbabwe' 'Togo' 'Botswana' 'Nigeria']
#
# 1985
# least similar:
# ['Gabon' 'Algeria' 'Central African Republic' 'Comoros' 'Burkina Faso'
#  'Malawi' 'Chad' 'Equatorial Guinea' 'Eswatini' 'Seychelles']
# ''

# %%
similarity(1990)
# Out:
# 1990
# most similar:
# ['Mozambique' 'Zimbabwe' 'Guinea' 'United Republic of Tanzania' 'Namibia'
#  'Senegal' 'Congo' 'Djibouti' 'Ghana' 'Côte d’Ivoire']
#
# 1990
# least similar:
# ['Eritrea' 'Seychelles' 'Central African Republic' 'Liberia' 'Niger'
#  'South Africa' 'Sao Tome and Principe' 'Eswatini' 'Malawi'
#  'Equatorial Guinea']
# ''

# %%
similarity(1995)
# Out:
# 1995
# most similar:
# ['Mozambique' 'Zimbabwe' 'United Republic of Tanzania' 'Namibia'
#  'Botswana' 'Zambia' 'Congo' 'Senegal' 'Djibouti' 'Ghana']
#
# 1995
# least similar:
# ['Sierra Leone' 'Central African Republic' 'Sao Tome and Principe'
#  'Burundi' 'Seychelles' 'Malawi' 'Equatorial Guinea' 'Rwanda' 'Eritrea'
#  'Eswatini']
# ''

# %%
similarity(2000)
# Out:
# 2000
# most similar:
# ['Congo' 'Botswana' 'Namibia' 'Algeria' 'Lesotho' 'Mozambique' 'Gabon'
#  'Zimbabwe' 'Guinea' 'Cabo Verde']
#
# 2000
# least similar:
# ['Malawi' 'Madagascar' 'Eritrea' 'Burkina Faso' 'Central African Republic'
#  'Sierra Leone' 'Eswatini' 'Côte d’Ivoire' 'Sao Tome and Principe'
#  'Equatorial Guinea']
# ''

# %%
similarity(2005)
# Out:
# 2005
# most similar:
# ['Gambia' 'Congo' 'Guinea' 'Lesotho' 'Côte d’Ivoire' 'Nigeria' 'Botswana'
#  'Algeria' 'Gabon' 'Mozambique']
#
# 2005
# least similar:
# ['Eswatini' 'Comoros' 'Tunisia' 'Somalia' 'Seychelles' 'Burkina Faso'
#  'Ethiopia' 'Eritrea' 'Djibouti' 'Malawi']
# ''

# %%
similarity(2010)
# Out:
# 2010
# most similar:
# ['Mozambique' 'Guinea' 'Congo' 'Namibia' 'Lesotho' 'Mauritania' 'Benin'
#  'Democratic Republic of the Congo' 'South Africa' 'Gambia']
#
# 2010
# least similar:
# ['Seychelles' 'Sao Tome and Principe' 'Madagascar' 'Malawi'
#  'Equatorial Guinea' 'South Sudan' 'Somalia' 'Tunisia' 'Burkina Faso'
#  'Ghana']
# ''

# %%
similarity(2015)
# Out:
# 2015
# most similar:
# ['Niger' 'Gabon' 'Lesotho' 'South Africa' 'Eswatini' 'Zimbabwe' 'Guinea'
#  'Côte d’Ivoire' 'Djibouti' 'Zambia']
#
# 2015
# least similar:
# ['Seychelles' 'Rwanda' 'Ghana' 'Libya' 'Uganda' 'South Sudan' 'Somalia'
#  'Egypt' 'Burkina Faso' 'Mauritius']
# ''
